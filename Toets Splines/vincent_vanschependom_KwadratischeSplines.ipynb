# %%
from vincent_vanschependom_KwadratischeSplines import *

# %%
x = sp.symbols('x')
g = rechte([1,3],[3,7]); g
# Out:
# <function vincent_vanschependom_KwadratischeSplines.rechte.<locals>.g(x)>

# %%
g(x)
# Out:
# 2*x + 1

# %%
f = parabool([1,3],[3,7],1); f
# Out:
# <function vincent_vanschependom_KwadratischeSplines.parabool.<locals>.f(x)>

# %%
f(x)
# Out:
# x**2/2 + 5/2

# %%
X = [1,3,4,6,8,16,20]
Y = [3,7,-1,9,11,19,15]

# %%
gi = koorden(X,Y)
[g(x) for g in gi]
# Out:
# [2*x + 1, 31 - 8*x, 5*x - 21, x + 3, x + 3, 35 - x]

# %%
m = sp.symbols('m')
fi = splines(X,Y,m)
[f(x) for f in fi]
# Out:
# [-3*m/2 + x**2*(1 - m/2) + x*(2*m - 2) + 4,
#  12*m + x**2*(m - 12) + x*(76 - 7*m) - 113,
#  -12*m + x**2*(25/2 - m/2) + x*(5*m - 120) + 279,
#  24*m + x**2*(m/2 - 29/2) + x*(204 - 7*m) - 693,
#  -16*m + x**2*(29/8 - m/8) + x*(3*m - 86) + 467,
#  80*m + x**2*(m/4 - 31/4) + x*(278 - 9*m) - 2445]

# %%
print(optimaal(X,Y))
# Out:
# 601*m**2/30 - 5764*m/5 + 16800
# 17292/601

# %%
figuur(X,Y)
# Out:
# 601*m**2/30 - 5764*m/5 + 16800
