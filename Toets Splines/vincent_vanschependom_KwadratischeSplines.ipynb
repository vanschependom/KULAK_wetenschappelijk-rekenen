# %%
from vincent_vanschependom_KwadratischeSplines import *

# %%
x = sp.symbols('x')
g = rechte([1,3],[3,7]); g
# Out:
# <function vincent_vanschependom_KwadratischeSplines.rechte.<locals>.g(x)>

# %%
g(x)
# Out:
# 2.0*x + 1.0

# %%
f = parabool([1,3],[3,7],1); f
# Out:
# <function vincent_vanschependom_KwadratischeSplines.parabool.<locals>.f(x)>

# %%
f(x)
# Out:
# x**2/2 + 5/2

# %%
X = [1,3,4,6,8,16,20]
Y = [3,7,-1,9,11,19,15]

# %%
gi = koorden(X,Y)
[g(x) for g in gi]
# Out:
# [2.0*x + 1.0,
#  31.0 - 8.0*x,
#  5.0*x - 21.0,
#  1.0*x + 3.0,
#  17.0 - 0.75*x,
#  0.555555555555556*x - 3.88888888888889]

# %%
m = sp.symbols('m')
fi = splines(X,Y,m)
[f(x) for f in fi]
# Out:
# [-3*m/2 + x**2*(1 - m/2) + x*(2*m - 2) + 4,
#  12*m + x**2*(m - 12) + x*(76 - 7*m) - 113,
#  -12*m + x**2*(25/2 - m/2) + x*(5*m - 120) + 279,
#  24*m + x**2*(m/2 - 29/2) + x*(204 - 7*m) - 693,
#  -16*m + x**2*(109/32 - m/8) + x*(3*m - 165/2) + 453,
#  400*m/9 + x**2*(m/9 - 467/162) + x*(19237/162 - 41*m/9) - 93715/81]

# %%
print(optimaal(X,Y))
# Out:
# 42.1999999999951*m**2 - 2221.69999999801*m + 29426.5416666724
# 26.3234597156193

# %%
figuur(X,Y)
# Out:
# 42.1999999999951*m**2 - 2221.69999999801*m + 29426.5416666724
